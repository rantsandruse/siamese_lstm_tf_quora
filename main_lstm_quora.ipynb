# %%
from lib import features_word2vec, model_siamese_lstm
import pandas as pd
import numpy as np
import os
# Out:
# /Users/sishitang/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /Users/sishitang/anaconda2/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# The next steps:
# 1. Check

# Will ingest/clean data and save the following:
# 1. cleaned text translated to array of word indices: imdb_indices.pickle
# 2. word2vec model, where the indices/word vecs are stored:  300features_40minwords_10context
# 3. word embeddings: this is the index to wordvec mapping derived from 2.

# ingestion clean data
# create word embedding
# create word indices that can be mapped to word embedding
labeled_data_path = "./data/train.csv"
model_path = "./model/300features_40minwords_10context_quora"
embedding_path = "./model/embedding_weights_quora.pkl"
text2indices_path = "./model/quora_indices.pickle"
maxSeqLength = 50

def data_prep_quora():
    # Read data
    # Use the kaggle Bag of words vs Bag of popcorn data:
    # https://www.kaggle.com/c/word2vec-nlp-tutorial/data

    data = pd.read_csv(labeled_data_path, delimiter=",", engine = "python", encoding = "utf8")
    data_concat = pd.concat([data[["question1"]], data[["question2"]].rename(columns={"question2":"question1"})], axis = 0)
    model = features_word2vec.get_word2vec_model(data_concat, "question1", num_features=300, downsampling=1e-3, model_path=model_path)

    embedding_weights = features_word2vec.create_embedding_weights(model, writeEmbeddingFileName = "./model/embedding_weights_quora_tmp.pkl" )

    features1 = features_word2vec.get_indices_word2vec(data, "question1", model, maxLength=maxSeqLength,
                                                             writeIndexFileName="./model/quora_indices1.pickle",
                                                             padLeft=True)
    features2 = features_word2vec.get_indices_word2vec(data, "question2", model, maxLength=maxSeqLength,
                                                         writeIndexFileName="./model/quora_indices2.pickle",
                                                         padLeft=True)
    label = data["is_duplicate"]

    return model, embedding_weights, features1, features2, label

# %%
# Run data prep routine if some files are not found
word2vecmodel, embedding_weights, features1, features2, label = data_prep_quora()

# %%
# Now build the model. 
model = model_siamese_lstm.SiameseLSTMModel(features1, features2, label, embedding_weights, maxSeqLength)
# Out:
# creating a new model:
#
# WARNING:tensorflow:From lib/model_siamese_lstm.py:140: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# (128, 1)

# %%
model.train_epochs(20)
# Out:
# Epoch 0:
#
# Iter 0, Minibatch Loss= 0.212235, Training Accuracy= 0.64844
# Iter 10, Minibatch Loss= 0.227772, Training Accuracy= 0.60156
# Iter 20, Minibatch Loss= 0.207841, Training Accuracy= 0.67188
# Iter 30, Minibatch Loss= 0.206541, Training Accuracy= 0.68750
# Iter 40, Minibatch Loss= 0.199944, Training Accuracy= 0.69531
# Iter 50, Minibatch Loss= 0.210343, Training Accuracy= 0.64844
# Iter 60, Minibatch Loss= 0.200991, Training Accuracy= 0.64844
# Iter 70, Minibatch Loss= 0.199569, Training Accuracy= 0.65625
# Iter 80, Minibatch Loss= 0.203254, Training Accuracy= 0.66406
# Iter 90, Minibatch Loss= 0.198378, Training Accuracy= 0.69531
# Iter 100, Minibatch Loss= 0.176983, Training Accuracy= 0.72656
# Iter 110, Minibatch Loss= 0.211288, Training Accuracy= 0.64844
# Iter 120, Minibatch Loss= 0.196117, Training Accuracy= 0.70312
# Iter 130, Minibatch Loss= 0.223076, Training Accuracy= 0.61719
# Iter 140, Minibatch Loss= 0.190076, Training Accuracy= 0.68750
# Iter 150, Minibatch Loss= 0.194873, Training Accuracy= 0.68750
# Iter 160, Minibatch Loss= 0.185809, Training Accuracy= 0.71875
# Iter 170, Minibatch Loss= 0.200985, Training Accuracy= 0.69531
# Iter 180, Minibatch Loss= 0.200761, Training Accuracy= 0.67969
# Iter 190, Minibatch Loss= 0.181738, Training Accuracy= 0.73438
# Iter 200, Minibatch Loss= 0.189517, Training Accuracy= 0.70312
# Iter 210, Minibatch Loss= 0.178516, Training Accuracy= 0.74219
# Iter 220, Minibatch Loss= 0.170898, Training Accuracy= 0.75000
# Iter 230, Minibatch Loss= 0.184551, Training Accuracy= 0.71875
# Iter 240, Minibatch Loss= 0.193908, Training Accuracy= 0.64062
# Iter 250, Minibatch Loss= 0.191307, Training Accuracy= 0.66406
# Iter 260, Minibatch Loss= 0.175381, Training Accuracy= 0.74219
# Iter 270, Minibatch Loss= 0.184010, Training Accuracy= 0.71094
# Iter 280, Minibatch Loss= 0.195932, Training Accuracy= 0.70312
# Iter 290, Minibatch Loss= 0.182070, Training Accuracy= 0.73438
# Iter 300, Minibatch Loss= 0.203199, Training Accuracy= 0.67188
# Iter 310, Minibatch Loss= 0.173614, Training Accuracy= 0.76562
# Iter 320, Minibatch Loss= 0.196983, Training Accuracy= 0.68750
# Iter 330, Minibatch Loss= 0.185066, Training Accuracy= 0.69531
# Iter 340, Minibatch Loss= 0.182801, Training Accuracy= 0.73438
# Iter 350, Minibatch Loss= 0.158906, Training Accuracy= 0.80469
# Iter 360, Minibatch Loss= 0.188982, Training Accuracy= 0.67188
# Iter 370, Minibatch Loss= 0.176142, Training Accuracy= 0.73438
# Iter 380, Minibatch Loss= 0.173695, Training Accuracy= 0.72656
# Iter 390, Minibatch Loss= 0.163007, Training Accuracy= 0.75000
# Iter 400, Minibatch Loss= 0.171270, Training Accuracy= 0.74219
# Iter 410, Minibatch Loss= 0.166511, Training Accuracy= 0.76562
# Iter 420, Minibatch Loss= 0.224361, Training Accuracy= 0.63281
# Iter 430, Minibatch Loss= 0.184693, Training Accuracy= 0.67188
# Iter 440, Minibatch Loss= 0.182123, Training Accuracy= 0.76562
# Iter 450, Minibatch Loss= 0.180612, Training Accuracy= 0.71094
# Iter 460, Minibatch Loss= 0.194999, Training Accuracy= 0.71875
# Iter 470, Minibatch Loss= 0.180255, Training Accuracy= 0.74219
# Iter 480, Minibatch Loss= 0.165568, Training Accuracy= 0.73438
# Iter 490, Minibatch Loss= 0.163896, Training Accuracy= 0.75000
# Iter 500, Minibatch Loss= 0.181174, Training Accuracy= 0.73438
# Iter 510, Minibatch Loss= 0.169231, Training Accuracy= 0.76562
# Iter 520, Minibatch Loss= 0.170761, Training Accuracy= 0.76562
# Iter 530, Minibatch Loss= 0.191229, Training Accuracy= 0.73438
# Iter 540, Minibatch Loss= 0.153368, Training Accuracy= 0.80469
# Iter 550, Minibatch Loss= 0.187981, Training Accuracy= 0.68750
# Iter 560, Minibatch Loss= 0.179226, Training Accuracy= 0.68750
# Iter 570, Minibatch Loss= 0.194614, Training Accuracy= 0.69531
# Iter 580, Minibatch Loss= 0.188111, Training Accuracy= 0.71875
# Iter 590, Minibatch Loss= 0.186835, Training Accuracy= 0.72656
# Iter 600, Minibatch Loss= 0.183255, Training Accuracy= 0.71094
# Iter 610, Minibatch Loss= 0.175369, Training Accuracy= 0.78125
# Iter 620, Minibatch Loss= 0.162664, Training Accuracy= 0.76562
# Iter 630, Minibatch Loss= 0.153876, Training Accuracy= 0.77344
# Iter 640, Minibatch Loss= 0.187271, Training Accuracy= 0.72656
# Iter 650, Minibatch Loss= 0.162311, Training Accuracy= 0.74219
# Iter 660, Minibatch Loss= 0.176092, Training Accuracy= 0.75000
# Iter 670, Minibatch Loss= 0.172701, Training Accuracy= 0.75000
# Iter 680, Minibatch Loss= 0.176408, Training Accuracy= 0.73438
# Iter 690, Minibatch Loss= 0.157176, Training Accuracy= 0.78125
# Iter 700, Minibatch Loss= 0.163402, Training Accuracy= 0.74219
# Iter 710, Minibatch Loss= 0.181663, Training Accuracy= 0.71094
# Iter 720, Minibatch Loss= 0.166837, Training Accuracy= 0.75781
# Iter 730, Minibatch Loss= 0.207622, Training Accuracy= 0.67969
# Iter 740, Minibatch Loss= 0.199492, Training Accuracy= 0.68750
# Iter 750, Minibatch Loss= 0.160639, Training Accuracy= 0.76562
# Iter 760, Minibatch Loss= 0.176226, Training Accuracy= 0.73438
# Iter 770, Minibatch Loss= 0.194601, Training Accuracy= 0.69531
# Iter 780, Minibatch Loss= 0.185916, Training Accuracy= 0.72656
# Iter 790, Minibatch Loss= 0.172421, Training Accuracy= 0.73438
# Iter 800, Minibatch Loss= 0.207052, Training Accuracy= 0.66406
# Iter 810, Minibatch Loss= 0.179583, Training Accuracy= 0.75781
# Iter 820, Minibatch Loss= 0.187934, Training Accuracy= 0.71094
# Iter 830, Minibatch Loss= 0.199015, Training Accuracy= 0.68750
# Iter 840, Minibatch Loss= 0.175638, Training Accuracy= 0.72656
# Iter 850, Minibatch Loss= 0.176142, Training Accuracy= 0.73438
# Iter 860, Minibatch Loss= 0.177087, Training Accuracy= 0.75781
# Iter 870, Minibatch Loss= 0.170125, Training Accuracy= 0.75000
# Iter 880, Minibatch Loss= 0.138690, Training Accuracy= 0.81250
# Iter 890, Minibatch Loss= 0.172826, Training Accuracy= 0.75781
# Iter 900, Minibatch Loss= 0.155594, Training Accuracy= 0.75781
# Iter 910, Minibatch Loss= 0.186927, Training Accuracy= 0.70312
# Iter 920, Minibatch Loss= 0.199479, Training Accuracy= 0.67188
# Iter 930, Minibatch Loss= 0.184767, Training Accuracy= 0.71875
# Iter 940, Minibatch Loss= 0.194643, Training Accuracy= 0.67188
# Iter 950, Minibatch Loss= 0.193348, Training Accuracy= 0.67969
# Iter 960, Minibatch Loss= 0.150212, Training Accuracy= 0.79688
# Iter 970, Minibatch Loss= 0.173753, Training Accuracy= 0.74219
# Iter 980, Minibatch Loss= 0.176835, Training Accuracy= 0.72656
# Iter 990, Minibatch Loss= 0.172705, Training Accuracy= 0.74219
# Iter 1000, Minibatch Loss= 0.186684, Training Accuracy= 0.67969
# Iter 1010, Minibatch Loss= 0.176378, Training Accuracy= 0.74219
# Iter 1020, Minibatch Loss= 0.184661, Training Accuracy= 0.73438
# Iter 1030, Minibatch Loss= 0.159873, Training Accuracy= 0.80469
# Iter 1040, Minibatch Loss= 0.156707, Training Accuracy= 0.75000
# Iter 1050, Minibatch Loss= 0.193786, Training Accuracy= 0.68750
# Iter 1060, Minibatch Loss= 0.191591, Training Accuracy= 0.70312
# Iter 1070, Minibatch Loss= 0.173773, Training Accuracy= 0.72656
# Iter 1080, Minibatch Loss= 0.200765, Training Accuracy= 0.68750
# Iter 1090, Minibatch Loss= 0.202753, Training Accuracy= 0.71875
# Iter 1100, Minibatch Loss= 0.198162, Training Accuracy= 0.70312
# Iter 1110, Minibatch Loss= 0.174927, Training Accuracy= 0.72656
# Iter 1120, Minibatch Loss= 0.183643, Training Accuracy= 0.68750
# Iter 1130, Minibatch Loss= 0.153113, Training Accuracy= 0.78125
# Iter 1140, Minibatch Loss= 0.192400, Training Accuracy= 0.71094
# Iter 1150, Minibatch Loss= 0.185905, Training Accuracy= 0.74219
# Iter 1160, Minibatch Loss= 0.193285, Training Accuracy= 0.72656
# Iter 1170, Minibatch Loss= 0.145289, Training Accuracy= 0.79688
# Iter 1180, Minibatch Loss= 0.186489, Training Accuracy= 0.74219
# Iter 1190, Minibatch Loss= 0.170840, Training Accuracy= 0.75000
# Iter 1200, Minibatch Loss= 0.160809, Training Accuracy= 0.78125
# Iter 1210, Minibatch Loss= 0.213796, Training Accuracy= 0.69531
# Iter 1220, Minibatch Loss= 0.155663, Training Accuracy= 0.75000
# Iter 1230, Minibatch Loss= 0.178039, Training Accuracy= 0.75000
# Iter 1240, Minibatch Loss= 0.177149, Training Accuracy= 0.71875
# Iter 1250, Minibatch Loss= 0.159182, Training Accuracy= 0.75000
# Iter 1260, Minibatch Loss= 0.186855, Training Accuracy= 0.74219
# Iter 1270, Minibatch Loss= 0.174610, Training Accuracy= 0.74219
# Iter 1280, Minibatch Loss= 0.180554, Training Accuracy= 0.71875
# Iter 1290, Minibatch Loss= 0.188272, Training Accuracy= 0.70312
# Iter 1300, Minibatch Loss= 0.174467, Training Accuracy= 0.71875
# Iter 1310, Minibatch Loss= 0.184363, Training Accuracy= 0.70312
# Iter 1320, Minibatch Loss= 0.188367, Training Accuracy= 0.76562
# Iter 1330, Minibatch Loss= 0.179590, Training Accuracy= 0.71094
# Iter 1340, Minibatch Loss= 0.171079, Training Accuracy= 0.75781
# Iter 1350, Minibatch Loss= 0.160546, Training Accuracy= 0.78125
# Iter 1360, Minibatch Loss= 0.167730, Training Accuracy= 0.77344
# Iter 1370, Minibatch Loss= 0.173889, Training Accuracy= 0.71875
# Iter 1380, Minibatch Loss= 0.175949, Training Accuracy= 0.76562
# Iter 1390, Minibatch Loss= 0.170787, Training Accuracy= 0.79688
# Iter 1400, Minibatch Loss= 0.134427, Training Accuracy= 0.85938
# Iter 1410, Minibatch Loss= 0.163293, Training Accuracy= 0.75781
# Iter 1420, Minibatch Loss= 0.177846, Training Accuracy= 0.71875
# Iter 1430, Minibatch Loss= 0.173844, Training Accuracy= 0.73438
# Iter 1440, Minibatch Loss= 0.167980, Training Accuracy= 0.72656
# Iter 1450, Minibatch Loss= 0.169472, Training Accuracy= 0.77344
# Iter 1460, Minibatch Loss= 0.164213, Training Accuracy= 0.78906
# Iter 1470, Minibatch Loss= 0.161423, Training Accuracy= 0.78906
# Iter 1480, Minibatch Loss= 0.158665, Training Accuracy= 0.75000
# Iter 1490, Minibatch Loss= 0.166966, Training Accuracy= 0.74219
# Iter 1500, Minibatch Loss= 0.164965, Training Accuracy= 0.77344
# Iter 1510, Minibatch Loss= 0.147253, Training Accuracy= 0.83594
# Iter 1520, Minibatch Loss= 0.180021, Training Accuracy= 0.70312
# Iter 1530, Minibatch Loss= 0.168875, Training Accuracy= 0.75781
# Iter 1540, Minibatch Loss= 0.148442, Training Accuracy= 0.78125
# Iter 1550, Minibatch Loss= 0.173292, Training Accuracy= 0.73438
# Iter 1560, Minibatch Loss= 0.186041, Training Accuracy= 0.72656
# Iter 1570, Minibatch Loss= 0.165539, Training Accuracy= 0.75000
# Iter 1580, Minibatch Loss= 0.184583, Training Accuracy= 0.75000
# Iter 1590, Minibatch Loss= 0.168423, Training Accuracy= 0.76562
# Iter 1600, Minibatch Loss= 0.164192, Training Accuracy= 0.74219
# Iter 1610, Minibatch Loss= 0.163133, Training Accuracy= 0.75000
# Iter 1620, Minibatch Loss= 0.162278, Training Accuracy= 0.74219
# Iter 1630, Minibatch Loss= 0.179631, Training Accuracy= 0.72656
# Iter 1640, Minibatch Loss= 0.192882, Training Accuracy= 0.74219
# Iter 1650, Minibatch Loss= 0.193410, Training Accuracy= 0.69531
# Iter 1660, Minibatch Loss= 0.167853, Training Accuracy= 0.74219
# Iter 1670, Minibatch Loss= 0.190177, Training Accuracy= 0.72656
# Iter 1680, Minibatch Loss= 0.169290, Training Accuracy= 0.71875
# Iter 1690, Minibatch Loss= 0.167554, Training Accuracy= 0.73438
# Iter 1700, Minibatch Loss= 0.184350, Training Accuracy= 0.73438
# Iter 1710, Minibatch Loss= 0.184280, Training Accuracy= 0.68750
# Iter 1720, Minibatch Loss= 0.186207, Training Accuracy= 0.74219
# Iter 1730, Minibatch Loss= 0.153384, Training Accuracy= 0.78906
# Iter 1740, Minibatch Loss= 0.168917, Training Accuracy= 0.75000
# Iter 1750, Minibatch Loss= 0.167587, Training Accuracy= 0.76562
# Iter 1760, Minibatch Loss= 0.162677, Training Accuracy= 0.75781
# Iter 1770, Minibatch Loss= 0.170509, Training Accuracy= 0.74219
# Iter 1780, Minibatch Loss= 0.159226, Training Accuracy= 0.74219
# Iter 1790, Minibatch Loss= 0.164695, Training Accuracy= 0.78125
# Iter 1800, Minibatch Loss= 0.182389, Training Accuracy= 0.70312
# Iter 1810, Minibatch Loss= 0.162026, Training Accuracy= 0.71094
# Iter 1820, Minibatch Loss= 0.204226, Training Accuracy= 0.70312
# Iter 1830, Minibatch Loss= 0.151322, Training Accuracy= 0.80469
# Iter 1840, Minibatch Loss= 0.188419, Training Accuracy= 0.69531
# Iter 1850, Minibatch Loss= 0.177829, Training Accuracy= 0.73438
# Iter 1860, Minibatch Loss= 0.139186, Training Accuracy= 0.81250
# Iter 1870, Minibatch Loss= 0.176518, Training Accuracy= 0.71875
# Iter 1880, Minibatch Loss= 0.162024, Training Accuracy= 0.78906
# Iter 1890, Minibatch Loss= 0.158663, Training Accuracy= 0.80469
# Iter 1900, Minibatch Loss= 0.163331, Training Accuracy= 0.75000
# Iter 1910, Minibatch Loss= 0.178780, Training Accuracy= 0.71094
# Iter 1920, Minibatch Loss= 0.161583, Training Accuracy= 0.77344
# Iter 1930, Minibatch Loss= 0.167712, Training Accuracy= 0.76562
# Iter 1940, Minibatch Loss= 0.165329, Training Accuracy= 0.76562
# Iter 1950, Minibatch Loss= 0.188697, Training Accuracy= 0.71094
# Iter 1960, Minibatch Loss= 0.195988, Training Accuracy= 0.68750
# Iter 1970, Minibatch Loss= 0.148274, Training Accuracy= 0.79688
# Iter 1980, Minibatch Loss= 0.172728, Training Accuracy= 0.75781
# Iter 1990, Minibatch Loss= 0.170082, Training Accuracy= 0.74219
# Iter 2000, Minibatch Loss= 0.160193, Training Accuracy= 0.73438
# Iter 2010, Minibatch Loss= 0.178027, Training Accuracy= 0.75000
# Iter 2020, Minibatch Loss= 0.167570, Training Accuracy= 0.78125
# Iter 2030, Minibatch Loss= 0.156797, Training Accuracy= 0.74219
# Iter 2040, Minibatch Loss= 0.163037, Training Accuracy= 0.70312
# Iter 2050, Minibatch Loss= 0.185107, Training Accuracy= 0.70312
# Iter 2060, Minibatch Loss= 0.159874, Training Accuracy= 0.76562
# Iter 2070, Minibatch Loss= 0.164327, Training Accuracy= 0.79688
# Iter 2080, Minibatch Loss= 0.185495, Training Accuracy= 0.75781
# Iter 2090, Minibatch Loss= 0.173088, Training Accuracy= 0.76562
# Iter 2100, Minibatch Loss= 0.158233, Training Accuracy= 0.80469
# Iter 2110, Minibatch Loss= 0.157003, Training Accuracy= 0.77344
# Iter 2120, Minibatch Loss= 0.172939, Training Accuracy= 0.77344
# Iter 2130, Minibatch Loss= 0.179543, Training Accuracy= 0.71094
# Iter 2140, Minibatch Loss= 0.159572, Training Accuracy= 0.77344
# Iter 2150, Minibatch Loss= 0.186877, Training Accuracy= 0.73438
# Iter 2160, Minibatch Loss= 0.182559, Training Accuracy= 0.72656
# Iter 2170, Minibatch Loss= 0.151214, Training Accuracy= 0.78125
# Iter 2180, Minibatch Loss= 0.157588, Training Accuracy= 0.78125
# Iter 2190, Minibatch Loss= 0.187153, Training Accuracy= 0.70312
# Iter 2200, Minibatch Loss= 0.181722, Training Accuracy= 0.74219
# Iter 2210, Minibatch Loss= 0.178747, Training Accuracy= 0.74219
# Iter 2220, Minibatch Loss= 0.182122, Training Accuracy= 0.77344
# Iter 2230, Minibatch Loss= 0.152439, Training Accuracy= 0.79688
# Iter 2240, Minibatch Loss= 0.155609, Training Accuracy= 0.79688
# Iter 2250, Minibatch Loss= 0.174259, Training Accuracy= 0.73438
# Iter 2260, Minibatch Loss= 0.185020, Training Accuracy= 0.72656
# Iter 2270, Minibatch Loss= 0.164897, Training Accuracy= 0.80469
# Iter 2280, Minibatch Loss= 0.192023, Training Accuracy= 0.71875
# Iter 2290, Minibatch Loss= 0.171813, Training Accuracy= 0.75000
# Iter 2300, Minibatch Loss= 0.168787, Training Accuracy= 0.81250
# Iter 2310, Minibatch Loss= 0.195029, Training Accuracy= 0.69531
# Iter 2320, Minibatch Loss= 0.166891, Training Accuracy= 0.75000
# Iter 2330, Minibatch Loss= 0.158013, Training Accuracy= 0.78125
# Iter 2340, Minibatch Loss= 0.143143, Training Accuracy= 0.77344
# Iter 2350, Minibatch Loss= 0.201550, Training Accuracy= 0.67188
# Iter 2360, Minibatch Loss= 0.175546, Training Accuracy= 0.77344
# Iter 2370, Minibatch Loss= 0.192858, Training Accuracy= 0.71875
# Iter 2380, Minibatch Loss= 0.167453, Training Accuracy= 0.75000
# Iter 2390, Minibatch Loss= 0.170771, Training Accuracy= 0.75781
# Iter 2400, Minibatch Loss= 0.162711, Training Accuracy= 0.78906
# Iter 2410, Minibatch Loss= 0.156192, Training Accuracy= 0.78906
# Iter 2420, Minibatch Loss= 0.182845, Training Accuracy= 0.73438
# Iter 2430, Minibatch Loss= 0.180301, Training Accuracy= 0.71094
# Iter 2440, Minibatch Loss= 0.164839, Training Accuracy= 0.75781
# Iter 2450, Minibatch Loss= 0.183591, Training Accuracy= 0.72656
# Iter 2460, Minibatch Loss= 0.165578, Training Accuracy= 0.77344
# Iter 2470, Minibatch Loss= 0.199808, Training Accuracy= 0.65625
# Iter 2480, Minibatch Loss= 0.156590, Training Accuracy= 0.77344
# Iter 2490, Minibatch Loss= 0.174783, Training Accuracy= 0.75781
# Iter 2500, Minibatch Loss= 0.147822, Training Accuracy= 0.82812
# Iter 2510, Minibatch Loss= 0.143685, Training Accuracy= 0.82031
# Iter 2520, Minibatch Loss= 0.166245, Training Accuracy= 0.78125
# Iter 2530, Minibatch Loss= 0.191135, Training Accuracy= 0.71875
# Iter 2540, Minibatch Loss= 0.131646, Training Accuracy= 0.86719
# Iter 2550, Minibatch Loss= 0.172226, Training Accuracy= 0.75781
# Iter 2560, Minibatch Loss= 0.141608, Training Accuracy= 0.81250
# Iter 2570, Minibatch Loss= 0.160347, Training Accuracy= 0.75781
# Iter 2580, Minibatch Loss= 0.172259, Training Accuracy= 0.75000
# Iter 2590, Minibatch Loss= 0.190925, Training Accuracy= 0.71094
# Iter 2600, Minibatch Loss= 0.164712, Training Accuracy= 0.71094
# Iter 2610, Minibatch Loss= 0.182125, Training Accuracy= 0.70312
# Iter 2620, Minibatch Loss= 0.181077, Training Accuracy= 0.72656
# Iter 2630, Minibatch Loss= 0.157634, Training Accuracy= 0.75000
# Iter 2640, Minibatch Loss= 0.171303, Training Accuracy= 0.74219
# Iter 2650, Minibatch Loss= 0.172733, Training Accuracy= 0.75000
# Iter 2660, Minibatch Loss= 0.211561, Training Accuracy= 0.64062
# Iter 2670, Minibatch Loss= 0.205542, Training Accuracy= 0.67969
# Iter 2680, Minibatch Loss= 0.156420, Training Accuracy= 0.82812
# Iter 2690, Minibatch Loss= 0.151065, Training Accuracy= 0.78125
# Iter 2700, Minibatch Loss= 0.171618, Training Accuracy= 0.74219
# Iter 2710, Minibatch Loss= 0.162669, Training Accuracy= 0.75781
# Iter 2720, Minibatch Loss= 0.155334, Training Accuracy= 0.81250
# Iter 2730, Minibatch Loss= 0.180645, Training Accuracy= 0.75781
# Iter 2740, Minibatch Loss= 0.150015, Training Accuracy= 0.81250
# Iter 2750, Minibatch Loss= 0.169913, Training Accuracy= 0.79688
# Iter 2760, Minibatch Loss= 0.169468, Training Accuracy= 0.71094
# Iter 2770, Minibatch Loss= 0.153130, Training Accuracy= 0.78906
# Iter 2780, Minibatch Loss= 0.175186, Training Accuracy= 0.71094
# Iter 2790, Minibatch Loss= 0.142423, Training Accuracy= 0.81250
# Iter 2800, Minibatch Loss= 0.162378, Training Accuracy= 0.78125
# Iter 2810, Minibatch Loss= 0.161342, Training Accuracy= 0.78125
# Iter 2820, Minibatch Loss= 0.172113, Training Accuracy= 0.71875
# Iter 2830, Minibatch Loss= 0.187113, Training Accuracy= 0.74219
# Iter 2840, Minibatch Loss= 0.176337, Training Accuracy= 0.73438
# Testing accuracy = 0.76084
# saved to ./model/pretrained_lstm_tf.model
# Epoch 1:
#
# Iter 0, Minibatch Loss= 0.186946, Training Accuracy= 0.76562
# Iter 10, Minibatch Loss= 0.151414, Training Accuracy= 0.79688
# Iter 20, Minibatch Loss= 0.142366, Training Accuracy= 0.79688
# Iter 30, Minibatch Loss= 0.156997, Training Accuracy= 0.78125
# Iter 40, Minibatch Loss= 0.171468, Training Accuracy= 0.78125
# Iter 50, Minibatch Loss= 0.167734, Training Accuracy= 0.75781
# Iter 60, Minibatch Loss= 0.156321, Training Accuracy= 0.75781
# Iter 70, Minibatch Loss= 0.160335, Training Accuracy= 0.78906
# Iter 80, Minibatch Loss= 0.159494, Training Accuracy= 0.75781
# Iter 90, Minibatch Loss= 0.174114, Training Accuracy= 0.71875
# Iter 100, Minibatch Loss= 0.171680, Training Accuracy= 0.73438
# Iter 110, Minibatch Loss= 0.147925, Training Accuracy= 0.79688
# Iter 120, Minibatch Loss= 0.141977, Training Accuracy= 0.82812
# Iter 130, Minibatch Loss= 0.157528, Training Accuracy= 0.75000
# Iter 140, Minibatch Loss= 0.152699, Training Accuracy= 0.75000
# Iter 150, Minibatch Loss= 0.186757, Training Accuracy= 0.74219
# Iter 160, Minibatch Loss= 0.185945, Training Accuracy= 0.75000
# Iter 170, Minibatch Loss= 0.163618, Training Accuracy= 0.75000
# Iter 180, Minibatch Loss= 0.182785, Training Accuracy= 0.74219
# Iter 190, Minibatch Loss= 0.152380, Training Accuracy= 0.79688
# Iter 200, Minibatch Loss= 0.202501, Training Accuracy= 0.69531
# Iter 210, Minibatch Loss= 0.146702, Training Accuracy= 0.80469
# Iter 220, Minibatch Loss= 0.147933, Training Accuracy= 0.79688
# Iter 230, Minibatch Loss= 0.179066, Training Accuracy= 0.71875
# Iter 240, Minibatch Loss= 0.133528, Training Accuracy= 0.81250
# Iter 250, Minibatch Loss= 0.143007, Training Accuracy= 0.79688
# Iter 260, Minibatch Loss= 0.169501, Training Accuracy= 0.75000
# Iter 270, Minibatch Loss= 0.168883, Training Accuracy= 0.76562
# Iter 280, Minibatch Loss= 0.140505, Training Accuracy= 0.82031
# Iter 290, Minibatch Loss= 0.154986, Training Accuracy= 0.80469
# Iter 300, Minibatch Loss= 0.179720, Training Accuracy= 0.71094
# Iter 310, Minibatch Loss= 0.183026, Training Accuracy= 0.71875
# Iter 320, Minibatch Loss= 0.189510, Training Accuracy= 0.68750
# Iter 330, Minibatch Loss= 0.191366, Training Accuracy= 0.71875
# Iter 340, Minibatch Loss= 0.151959, Training Accuracy= 0.79688
# Iter 350, Minibatch Loss= 0.194845, Training Accuracy= 0.68750
# Iter 360, Minibatch Loss= 0.143313, Training Accuracy= 0.83594
# Iter 370, Minibatch Loss= 0.181466, Training Accuracy= 0.74219
# Iter 380, Minibatch Loss= 0.188676, Training Accuracy= 0.71875
# Iter 390, Minibatch Loss= 0.162411, Training Accuracy= 0.74219
# Iter 400, Minibatch Loss= 0.169173, Training Accuracy= 0.78906
# Iter 410, Minibatch Loss= 0.153013, Training Accuracy= 0.75781
# Iter 420, Minibatch Loss= 0.152670, Training Accuracy= 0.79688
# Iter 430, Minibatch Loss= 0.153922, Training Accuracy= 0.75000
# Iter 440, Minibatch Loss= 0.165436, Training Accuracy= 0.72656
# Iter 450, Minibatch Loss= 0.143212, Training Accuracy= 0.81250
# Iter 460, Minibatch Loss= 0.144979, Training Accuracy= 0.78906
# Iter 470, Minibatch Loss= 0.167334, Training Accuracy= 0.74219
# Iter 480, Minibatch Loss= 0.140363, Training Accuracy= 0.81250
# Iter 490, Minibatch Loss= 0.154064, Training Accuracy= 0.78125
# Iter 500, Minibatch Loss= 0.150671, Training Accuracy= 0.79688
# Iter 510, Minibatch Loss= 0.151123, Training Accuracy= 0.80469
# Iter 520, Minibatch Loss= 0.158871, Training Accuracy= 0.76562
# Iter 530, Minibatch Loss= 0.177231, Training Accuracy= 0.73438
# Iter 540, Minibatch Loss= 0.161742, Training Accuracy= 0.79688
# Iter 550, Minibatch Loss= 0.183241, Training Accuracy= 0.77344
# Iter 560, Minibatch Loss= 0.177911, Training Accuracy= 0.75000
# Iter 570, Minibatch Loss= 0.175521, Training Accuracy= 0.78125
# Iter 580, Minibatch Loss= 0.157945, Training Accuracy= 0.79688
# Iter 590, Minibatch Loss= 0.165489, Training Accuracy= 0.76562
# Iter 600, Minibatch Loss= 0.160777, Training Accuracy= 0.79688
# Iter 610, Minibatch Loss= 0.168176, Training Accuracy= 0.76562
# Iter 620, Minibatch Loss= 0.170353, Training Accuracy= 0.70312
# Iter 630, Minibatch Loss= 0.163009, Training Accuracy= 0.77344
# Iter 640, Minibatch Loss= 0.179022, Training Accuracy= 0.69531
# Iter 650, Minibatch Loss= 0.161494, Training Accuracy= 0.75000
# Iter 660, Minibatch Loss= 0.184705, Training Accuracy= 0.73438
# Iter 670, Minibatch Loss= 0.187295, Training Accuracy= 0.68750
# Iter 680, Minibatch Loss= 0.161840, Training Accuracy= 0.79688
# Iter 690, Minibatch Loss= 0.171340, Training Accuracy= 0.73438
# Iter 700, Minibatch Loss= 0.143627, Training Accuracy= 0.80469
# Iter 710, Minibatch Loss= 0.176970, Training Accuracy= 0.67969
# Iter 720, Minibatch Loss= 0.168373, Training Accuracy= 0.72656
# Iter 730, Minibatch Loss= 0.162945, Training Accuracy= 0.75781
# Iter 740, Minibatch Loss= 0.169605, Training Accuracy= 0.74219
# Iter 750, Minibatch Loss= 0.183683, Training Accuracy= 0.76562
# Iter 760, Minibatch Loss= 0.152071, Training Accuracy= 0.82031
# Iter 770, Minibatch Loss= 0.164926, Training Accuracy= 0.81250
# Iter 780, Minibatch Loss= 0.176241, Training Accuracy= 0.74219
# Iter 790, Minibatch Loss= 0.170967, Training Accuracy= 0.77344
# Iter 800, Minibatch Loss= 0.130880, Training Accuracy= 0.83594
# Iter 810, Minibatch Loss= 0.161320, Training Accuracy= 0.76562
# Iter 820, Minibatch Loss= 0.158553, Training Accuracy= 0.77344
# Iter 830, Minibatch Loss= 0.128657, Training Accuracy= 0.89062
# Iter 840, Minibatch Loss= 0.143815, Training Accuracy= 0.78906
# Iter 850, Minibatch Loss= 0.187083, Training Accuracy= 0.68750
# Iter 860, Minibatch Loss= 0.175593, Training Accuracy= 0.74219
# Iter 870, Minibatch Loss= 0.152221, Training Accuracy= 0.77344
# Iter 880, Minibatch Loss= 0.154094, Training Accuracy= 0.78125
# Iter 890, Minibatch Loss= 0.155692, Training Accuracy= 0.77344
# Iter 900, Minibatch Loss= 0.157082, Training Accuracy= 0.78125
# Iter 910, Minibatch Loss= 0.164225, Training Accuracy= 0.79688
# Iter 920, Minibatch Loss= 0.145161, Training Accuracy= 0.78125
# Iter 930, Minibatch Loss= 0.176208, Training Accuracy= 0.77344
# Iter 940, Minibatch Loss= 0.165013, Training Accuracy= 0.78125
# Iter 950, Minibatch Loss= 0.160039, Training Accuracy= 0.76562
# Iter 960, Minibatch Loss= 0.178419, Training Accuracy= 0.74219
# Iter 970, Minibatch Loss= 0.146116, Training Accuracy= 0.80469
# Iter 980, Minibatch Loss= 0.166437, Training Accuracy= 0.78125
# Iter 990, Minibatch Loss= 0.137025, Training Accuracy= 0.79688
# Iter 1000, Minibatch Loss= 0.159828, Training Accuracy= 0.79688
# Iter 1010, Minibatch Loss= 0.185587, Training Accuracy= 0.71094
# Iter 1020, Minibatch Loss= 0.174045, Training Accuracy= 0.71875
# Iter 1030, Minibatch Loss= 0.177869, Training Accuracy= 0.73438
# Iter 1040, Minibatch Loss= 0.168626, Training Accuracy= 0.77344
# Iter 1050, Minibatch Loss= 0.159537, Training Accuracy= 0.79688
# Iter 1060, Minibatch Loss= 0.147140, Training Accuracy= 0.78906
# Iter 1070, Minibatch Loss= 0.169232, Training Accuracy= 0.75000
# Iter 1080, Minibatch Loss= 0.154609, Training Accuracy= 0.78125
# Iter 1090, Minibatch Loss= 0.170948, Training Accuracy= 0.75781
# Iter 1100, Minibatch Loss= 0.167257, Training Accuracy= 0.74219
# Iter 1110, Minibatch Loss= 0.180677, Training Accuracy= 0.72656
# Iter 1120, Minibatch Loss= 0.186255, Training Accuracy= 0.67969
# Iter 1130, Minibatch Loss= 0.182883, Training Accuracy= 0.71875
# Iter 1140, Minibatch Loss= 0.182280, Training Accuracy= 0.71875
# Iter 1150, Minibatch Loss= 0.158415, Training Accuracy= 0.76562
# Iter 1160, Minibatch Loss= 0.170107, Training Accuracy= 0.76562
# Iter 1170, Minibatch Loss= 0.174657, Training Accuracy= 0.74219
# Iter 1180, Minibatch Loss= 0.171470, Training Accuracy= 0.76562
# Iter 1190, Minibatch Loss= 0.158218, Training Accuracy= 0.73438
# Iter 1200, Minibatch Loss= 0.168218, Training Accuracy= 0.74219
# Iter 1210, Minibatch Loss= 0.169381, Training Accuracy= 0.77344
# Iter 1220, Minibatch Loss= 0.157446, Training Accuracy= 0.72656
# Iter 1230, Minibatch Loss= 0.158229, Training Accuracy= 0.79688
# Iter 1240, Minibatch Loss= 0.146796, Training Accuracy= 0.78125
# Iter 1250, Minibatch Loss= 0.153264, Training Accuracy= 0.80469
# Iter 1260, Minibatch Loss= 0.160572, Training Accuracy= 0.78125
# Iter 1270, Minibatch Loss= 0.161418, Training Accuracy= 0.76562
# Iter 1280, Minibatch Loss= 0.200624, Training Accuracy= 0.66406
# Iter 1290, Minibatch Loss= 0.163615, Training Accuracy= 0.75781
# Iter 1300, Minibatch Loss= 0.172642, Training Accuracy= 0.75781
# Iter 1310, Minibatch Loss= 0.167868, Training Accuracy= 0.74219
# Iter 1320, Minibatch Loss= 0.164370, Training Accuracy= 0.77344
# Iter 1330, Minibatch Loss= 0.137049, Training Accuracy= 0.82031
# Iter 1340, Minibatch Loss= 0.168691, Training Accuracy= 0.71875
# Iter 1350, Minibatch Loss= 0.148299, Training Accuracy= 0.83594
# Iter 1360, Minibatch Loss= 0.182338, Training Accuracy= 0.71094
# Iter 1370, Minibatch Loss= 0.160212, Training Accuracy= 0.76562
# Iter 1380, Minibatch Loss= 0.154696, Training Accuracy= 0.77344
# Iter 1390, Minibatch Loss= 0.179399, Training Accuracy= 0.72656
# Iter 1400, Minibatch Loss= 0.187887, Training Accuracy= 0.71875
# Iter 1410, Minibatch Loss= 0.174183, Training Accuracy= 0.74219
# Iter 1420, Minibatch Loss= 0.179018, Training Accuracy= 0.71875
# Iter 1430, Minibatch Loss= 0.150528, Training Accuracy= 0.78125
# Iter 1440, Minibatch Loss= 0.151764, Training Accuracy= 0.77344
# Iter 1450, Minibatch Loss= 0.182579, Training Accuracy= 0.69531
# Iter 1460, Minibatch Loss= 0.153271, Training Accuracy= 0.77344
# Iter 1470, Minibatch Loss= 0.150934, Training Accuracy= 0.78906
# Iter 1480, Minibatch Loss= 0.174387, Training Accuracy= 0.72656
# Iter 1490, Minibatch Loss= 0.136937, Training Accuracy= 0.80469
# Iter 1500, Minibatch Loss= 0.158280, Training Accuracy= 0.75000
# Iter 1510, Minibatch Loss= 0.150253, Training Accuracy= 0.80469
# Iter 1520, Minibatch Loss= 0.162772, Training Accuracy= 0.75781
# Iter 1530, Minibatch Loss= 0.152622, Training Accuracy= 0.78906
# Iter 1540, Minibatch Loss= 0.163785, Training Accuracy= 0.75781
# Iter 1550, Minibatch Loss= 0.163786, Training Accuracy= 0.72656
# Iter 1560, Minibatch Loss= 0.159388, Training Accuracy= 0.75781
# Iter 1570, Minibatch Loss= 0.141882, Training Accuracy= 0.76562
# Iter 1580, Minibatch Loss= 0.191857, Training Accuracy= 0.74219
# Iter 1590, Minibatch Loss= 0.171592, Training Accuracy= 0.75781
# Iter 1600, Minibatch Loss= 0.169442, Training Accuracy= 0.78906
# Iter 1610, Minibatch Loss= 0.179461, Training Accuracy= 0.69531
# Iter 1620, Minibatch Loss= 0.178519, Training Accuracy= 0.71094
# Iter 1630, Minibatch Loss= 0.177980, Training Accuracy= 0.75781
# Iter 1640, Minibatch Loss= 0.133742, Training Accuracy= 0.78906
# Iter 1650, Minibatch Loss= 0.158035, Training Accuracy= 0.79688
# Iter 1660, Minibatch Loss= 0.194453, Training Accuracy= 0.75781
# Iter 1670, Minibatch Loss= 0.163667, Training Accuracy= 0.79688
# Iter 1680, Minibatch Loss= 0.146939, Training Accuracy= 0.78906
# Iter 1690, Minibatch Loss= 0.149559, Training Accuracy= 0.79688
# Iter 1700, Minibatch Loss= 0.152081, Training Accuracy= 0.78906
# Iter 1710, Minibatch Loss= 0.166903, Training Accuracy= 0.72656
# Iter 1720, Minibatch Loss= 0.167150, Training Accuracy= 0.82031
# Iter 1730, Minibatch Loss= 0.148606, Training Accuracy= 0.78906
# Iter 1740, Minibatch Loss= 0.165375, Training Accuracy= 0.75000
# Iter 1750, Minibatch Loss= 0.169052, Training Accuracy= 0.74219
# Iter 1760, Minibatch Loss= 0.181789, Training Accuracy= 0.73438
# Iter 1770, Minibatch Loss= 0.161261, Training Accuracy= 0.70312
# Iter 1780, Minibatch Loss= 0.171206, Training Accuracy= 0.75781
# Iter 1790, Minibatch Loss= 0.140494, Training Accuracy= 0.80469
# Iter 1800, Minibatch Loss= 0.156302, Training Accuracy= 0.76562
# Iter 1810, Minibatch Loss= 0.116684, Training Accuracy= 0.88281
# Iter 1820, Minibatch Loss= 0.177399, Training Accuracy= 0.75000
# Iter 1830, Minibatch Loss= 0.161815, Training Accuracy= 0.75781
# Iter 1840, Minibatch Loss= 0.146670, Training Accuracy= 0.78125
# Iter 1850, Minibatch Loss= 0.146445, Training Accuracy= 0.80469
# Iter 1860, Minibatch Loss= 0.163087, Training Accuracy= 0.74219
# Iter 1870, Minibatch Loss= 0.160410, Training Accuracy= 0.74219
# Iter 1880, Minibatch Loss= 0.146101, Training Accuracy= 0.78906
# Iter 1890, Minibatch Loss= 0.151514, Training Accuracy= 0.76562
# Iter 1900, Minibatch Loss= 0.175496, Training Accuracy= 0.75000
# Iter 1910, Minibatch Loss= 0.149895, Training Accuracy= 0.74219
# Iter 1920, Minibatch Loss= 0.145935, Training Accuracy= 0.82812
# Iter 1930, Minibatch Loss= 0.176777, Training Accuracy= 0.74219
# Iter 1940, Minibatch Loss= 0.143296, Training Accuracy= 0.77344
# Iter 1950, Minibatch Loss= 0.176156, Training Accuracy= 0.75000
# Iter 1960, Minibatch Loss= 0.145930, Training Accuracy= 0.79688
# Iter 1970, Minibatch Loss= 0.173516, Training Accuracy= 0.70312
# Iter 1980, Minibatch Loss= 0.151495, Training Accuracy= 0.77344
# Iter 1990, Minibatch Loss= 0.164733, Training Accuracy= 0.77344
# Iter 2000, Minibatch Loss= 0.172448, Training Accuracy= 0.75000
# Iter 2010, Minibatch Loss= 0.176109, Training Accuracy= 0.74219
# Iter 2020, Minibatch Loss= 0.160682, Training Accuracy= 0.78125
# Iter 2030, Minibatch Loss= 0.135187, Training Accuracy= 0.79688
# Iter 2040, Minibatch Loss= 0.142149, Training Accuracy= 0.78125
# Iter 2050, Minibatch Loss= 0.160284, Training Accuracy= 0.76562
# Iter 2060, Minibatch Loss= 0.151947, Training Accuracy= 0.76562
# Iter 2070, Minibatch Loss= 0.185462, Training Accuracy= 0.71094
# Iter 2080, Minibatch Loss= 0.154787, Training Accuracy= 0.78125
# Iter 2090, Minibatch Loss= 0.155922, Training Accuracy= 0.75781
# Iter 2100, Minibatch Loss= 0.153988, Training Accuracy= 0.81250
# Iter 2110, Minibatch Loss= 0.171810, Training Accuracy= 0.75000
# Iter 2120, Minibatch Loss= 0.156382, Training Accuracy= 0.76562
# Iter 2130, Minibatch Loss= 0.161823, Training Accuracy= 0.75781
# Iter 2140, Minibatch Loss= 0.156636, Training Accuracy= 0.75000
# Iter 2150, Minibatch Loss= 0.146273, Training Accuracy= 0.78125
# Iter 2160, Minibatch Loss= 0.163112, Training Accuracy= 0.76562
# Iter 2170, Minibatch Loss= 0.157530, Training Accuracy= 0.77344
# Iter 2180, Minibatch Loss= 0.152645, Training Accuracy= 0.78125
# Iter 2190, Minibatch Loss= 0.173106, Training Accuracy= 0.71094
# Iter 2200, Minibatch Loss= 0.134297, Training Accuracy= 0.84375
# Iter 2210, Minibatch Loss= 0.161488, Training Accuracy= 0.75781
# Iter 2220, Minibatch Loss= 0.149938, Training Accuracy= 0.80469
# Iter 2230, Minibatch Loss= 0.153257, Training Accuracy= 0.78125
# Iter 2240, Minibatch Loss= 0.148775, Training Accuracy= 0.79688
# Iter 2250, Minibatch Loss= 0.174956, Training Accuracy= 0.73438
# Iter 2260, Minibatch Loss= 0.155205, Training Accuracy= 0.77344
# Iter 2270, Minibatch Loss= 0.168662, Training Accuracy= 0.75781
# Iter 2280, Minibatch Loss= 0.149979, Training Accuracy= 0.78125
# Iter 2290, Minibatch Loss= 0.151362, Training Accuracy= 0.77344
# Iter 2300, Minibatch Loss= 0.163011, Training Accuracy= 0.77344
# Iter 2310, Minibatch Loss= 0.154449, Training Accuracy= 0.75000
# Iter 2320, Minibatch Loss= 0.149832, Training Accuracy= 0.81250
# Iter 2330, Minibatch Loss= 0.169754, Training Accuracy= 0.75781
# Iter 2340, Minibatch Loss= 0.173156, Training Accuracy= 0.75000
# Iter 2350, Minibatch Loss= 0.187058, Training Accuracy= 0.71875
# Iter 2360, Minibatch Loss= 0.163970, Training Accuracy= 0.78125
# Iter 2370, Minibatch Loss= 0.166944, Training Accuracy= 0.77344
# Iter 2380, Minibatch Loss= 0.166625, Training Accuracy= 0.78125
# Iter 2390, Minibatch Loss= 0.169352, Training Accuracy= 0.77344
# Iter 2400, Minibatch Loss= 0.176205, Training Accuracy= 0.75000
# Iter 2410, Minibatch Loss= 0.152663, Training Accuracy= 0.80469
# Iter 2420, Minibatch Loss= 0.153709, Training Accuracy= 0.75781
# Iter 2430, Minibatch Loss= 0.175949, Training Accuracy= 0.72656
# Iter 2440, Minibatch Loss= 0.147845, Training Accuracy= 0.80469
# Iter 2450, Minibatch Loss= 0.162546, Training Accuracy= 0.75781
# Iter 2460, Minibatch Loss= 0.156222, Training Accuracy= 0.76562
# Iter 2470, Minibatch Loss= 0.150825, Training Accuracy= 0.83594
# Iter 2480, Minibatch Loss= 0.175763, Training Accuracy= 0.74219
# Iter 2490, Minibatch Loss= 0.165583, Training Accuracy= 0.74219
# Iter 2500, Minibatch Loss= 0.156989, Training Accuracy= 0.77344
# Iter 2510, Minibatch Loss= 0.159886, Training Accuracy= 0.78125
# Iter 2520, Minibatch Loss= 0.168895, Training Accuracy= 0.68750
# Iter 2530, Minibatch Loss= 0.160401, Training Accuracy= 0.75781
# Iter 2540, Minibatch Loss= 0.163652, Training Accuracy= 0.78906
# Iter 2550, Minibatch Loss= 0.172672, Training Accuracy= 0.77344
# Iter 2560, Minibatch Loss= 0.182303, Training Accuracy= 0.76562
# Iter 2570, Minibatch Loss= 0.152844, Training Accuracy= 0.75781
# Iter 2580, Minibatch Loss= 0.122952, Training Accuracy= 0.85156
# Iter 2590, Minibatch Loss= 0.176085, Training Accuracy= 0.77344
# Iter 2600, Minibatch Loss= 0.165677, Training Accuracy= 0.75781
# Iter 2610, Minibatch Loss= 0.159912, Training Accuracy= 0.76562
# Iter 2620, Minibatch Loss= 0.198285, Training Accuracy= 0.68750
# Iter 2630, Minibatch Loss= 0.160661, Training Accuracy= 0.77344
# Iter 2640, Minibatch Loss= 0.161178, Training Accuracy= 0.77344
# Iter 2650, Minibatch Loss= 0.139024, Training Accuracy= 0.83594
# Iter 2660, Minibatch Loss= 0.178473, Training Accuracy= 0.73438
# Iter 2670, Minibatch Loss= 0.177454, Training Accuracy= 0.73438
# Iter 2680, Minibatch Loss= 0.182211, Training Accuracy= 0.71094
# Iter 2690, Minibatch Loss= 0.183021, Training Accuracy= 0.74219
# Iter 2700, Minibatch Loss= 0.176328, Training Accuracy= 0.73438
# Iter 2710, Minibatch Loss= 0.157538, Training Accuracy= 0.78125
# Iter 2720, Minibatch Loss= 0.156365, Training Accuracy= 0.77344
# Iter 2730, Minibatch Loss= 0.159517, Training Accuracy= 0.81250
# Iter 2740, Minibatch Loss= 0.165341, Training Accuracy= 0.76562
# Iter 2750, Minibatch Loss= 0.146903, Training Accuracy= 0.77344
# Iter 2760, Minibatch Loss= 0.157958, Training Accuracy= 0.78906
# Iter 2770, Minibatch Loss= 0.161708, Training Accuracy= 0.78125
# Iter 2780, Minibatch Loss= 0.168517, Training Accuracy= 0.72656
# Iter 2790, Minibatch Loss= 0.146899, Training Accuracy= 0.79688
# Iter 2800, Minibatch Loss= 0.157696, Training Accuracy= 0.78125
# Iter 2810, Minibatch Loss= 0.166050, Training Accuracy= 0.81250
# Iter 2820, Minibatch Loss= 0.160060, Training Accuracy= 0.79688
# Iter 2830, Minibatch Loss= 0.155101, Training Accuracy= 0.75000
# Iter 2840, Minibatch Loss= 0.165608, Training Accuracy= 0.75000
# Testing accuracy = 0.77277
# Epoch 2:
#
# Iter 0, Minibatch Loss= 0.175309, Training Accuracy= 0.73438
# Iter 10, Minibatch Loss= 0.143990, Training Accuracy= 0.83594
# Iter 20, Minibatch Loss= 0.159090, Training Accuracy= 0.75000
# Iter 30, Minibatch Loss= 0.168705, Training Accuracy= 0.74219
# Iter 40, Minibatch Loss= 0.183047, Training Accuracy= 0.71094
# Iter 50, Minibatch Loss= 0.130251, Training Accuracy= 0.83594
# Iter 60, Minibatch Loss= 0.155717, Training Accuracy= 0.75781
# Iter 70, Minibatch Loss= 0.168837, Training Accuracy= 0.75781
# Iter 80, Minibatch Loss= 0.171354, Training Accuracy= 0.75781
# Iter 90, Minibatch Loss= 0.177668, Training Accuracy= 0.74219
# Iter 100, Minibatch Loss= 0.176289, Training Accuracy= 0.74219
# Iter 110, Minibatch Loss= 0.153500, Training Accuracy= 0.78906
# Iter 120, Minibatch Loss= 0.153118, Training Accuracy= 0.79688
# Iter 130, Minibatch Loss= 0.145377, Training Accuracy= 0.78125
# Iter 140, Minibatch Loss= 0.161617, Training Accuracy= 0.78906
# Iter 150, Minibatch Loss= 0.152843, Training Accuracy= 0.79688
# Iter 160, Minibatch Loss= 0.174468, Training Accuracy= 0.71094
# Iter 170, Minibatch Loss= 0.142460, Training Accuracy= 0.82031
# Iter 180, Minibatch Loss= 0.143254, Training Accuracy= 0.82031
# Iter 190, Minibatch Loss= 0.176725, Training Accuracy= 0.74219
# Iter 200, Minibatch Loss= 0.151081, Training Accuracy= 0.78125
# Iter 210, Minibatch Loss= 0.148835, Training Accuracy= 0.81250
# Iter 220, Minibatch Loss= 0.159697, Training Accuracy= 0.75781
# Iter 230, Minibatch Loss= 0.174188, Training Accuracy= 0.74219
# Iter 240, Minibatch Loss= 0.147679, Training Accuracy= 0.83594
# Iter 250, Minibatch Loss= 0.160467, Training Accuracy= 0.75781
# Iter 260, Minibatch Loss= 0.169728, Training Accuracy= 0.74219
# Iter 270, Minibatch Loss= 0.168336, Training Accuracy= 0.75781
# Iter 280, Minibatch Loss= 0.147545, Training Accuracy= 0.77344
# Iter 290, Minibatch Loss= 0.146260, Training Accuracy= 0.81250
# Iter 300, Minibatch Loss= 0.157247, Training Accuracy= 0.78906
# Iter 310, Minibatch Loss= 0.152020, Training Accuracy= 0.78125
# Iter 320, Minibatch Loss= 0.153865, Training Accuracy= 0.73438
# Iter 330, Minibatch Loss= 0.148066, Training Accuracy= 0.75781
# Iter 340, Minibatch Loss= 0.178419, Training Accuracy= 0.73438
# Iter 350, Minibatch Loss= 0.157166, Training Accuracy= 0.79688
# Iter 360, Minibatch Loss= 0.152258, Training Accuracy= 0.78906
# Iter 370, Minibatch Loss= 0.174976, Training Accuracy= 0.73438
# Iter 380, Minibatch Loss= 0.169191, Training Accuracy= 0.73438
# Iter 390, Minibatch Loss= 0.156324, Training Accuracy= 0.76562
# Iter 400, Minibatch Loss= 0.164224, Training Accuracy= 0.80469
# Iter 410, Minibatch Loss= 0.156298, Training Accuracy= 0.82031
# Iter 420, Minibatch Loss= 0.133932, Training Accuracy= 0.82031
# Iter 430, Minibatch Loss= 0.151053, Training Accuracy= 0.78906
# Iter 440, Minibatch Loss= 0.155688, Training Accuracy= 0.75781
# Iter 450, Minibatch Loss= 0.138080, Training Accuracy= 0.79688
# Iter 460, Minibatch Loss= 0.153935, Training Accuracy= 0.75000
# Iter 470, Minibatch Loss= 0.150708, Training Accuracy= 0.75781
# Iter 480, Minibatch Loss= 0.149381, Training Accuracy= 0.78906
# Iter 490, Minibatch Loss= 0.143143, Training Accuracy= 0.82812
# Iter 500, Minibatch Loss= 0.150918, Training Accuracy= 0.77344
# Iter 510, Minibatch Loss= 0.157311, Training Accuracy= 0.80469
# Iter 520, Minibatch Loss= 0.148892, Training Accuracy= 0.78125
# Iter 530, Minibatch Loss= 0.171138, Training Accuracy= 0.76562
# Iter 540, Minibatch Loss= 0.151570, Training Accuracy= 0.77344
# Iter 550, Minibatch Loss= 0.145172, Training Accuracy= 0.82031
# Iter 560, Minibatch Loss= 0.148949, Training Accuracy= 0.80469
# Iter 570, Minibatch Loss= 0.135980, Training Accuracy= 0.81250
# Iter 580, Minibatch Loss= 0.159508, Training Accuracy= 0.79688
# Iter 590, Minibatch Loss= 0.164808, Training Accuracy= 0.72656
# Iter 600, Minibatch Loss= 0.146716, Training Accuracy= 0.79688
# Iter 610, Minibatch Loss= 0.158972, Training Accuracy= 0.76562
# Iter 620, Minibatch Loss= 0.156939, Training Accuracy= 0.81250
# Iter 630, Minibatch Loss= 0.167843, Training Accuracy= 0.73438
# Iter 640, Minibatch Loss= 0.159527, Training Accuracy= 0.75000
# Iter 650, Minibatch Loss= 0.126510, Training Accuracy= 0.83594
# Iter 660, Minibatch Loss= 0.147658, Training Accuracy= 0.80469
# Iter 670, Minibatch Loss= 0.158525, Training Accuracy= 0.81250
# Iter 680, Minibatch Loss= 0.157241, Training Accuracy= 0.81250
# Iter 690, Minibatch Loss= 0.151051, Training Accuracy= 0.77344
# Iter 700, Minibatch Loss= 0.137364, Training Accuracy= 0.82812
# Iter 710, Minibatch Loss= 0.138430, Training Accuracy= 0.84375
# Iter 720, Minibatch Loss= 0.156312, Training Accuracy= 0.74219
# Iter 730, Minibatch Loss= 0.135735, Training Accuracy= 0.83594
# Iter 740, Minibatch Loss= 0.181984, Training Accuracy= 0.73438
# Iter 750, Minibatch Loss= 0.139561, Training Accuracy= 0.82031
# Iter 760, Minibatch Loss= 0.167335, Training Accuracy= 0.75781
# Iter 770, Minibatch Loss= 0.136342, Training Accuracy= 0.78906
# Iter 780, Minibatch Loss= 0.156110, Training Accuracy= 0.78906
# Iter 790, Minibatch Loss= 0.138783, Training Accuracy= 0.82812
# Iter 800, Minibatch Loss= 0.156125, Training Accuracy= 0.78125
# Iter 810, Minibatch Loss= 0.155654, Training Accuracy= 0.76562
# Iter 820, Minibatch Loss= 0.171752, Training Accuracy= 0.79688
# Iter 830, Minibatch Loss= 0.175844, Training Accuracy= 0.71094
# Iter 840, Minibatch Loss= 0.178308, Training Accuracy= 0.71875
# Iter 850, Minibatch Loss= 0.151195, Training Accuracy= 0.75781
# Iter 860, Minibatch Loss= 0.163782, Training Accuracy= 0.77344
# Iter 870, Minibatch Loss= 0.131763, Training Accuracy= 0.81250
# Iter 880, Minibatch Loss= 0.166146, Training Accuracy= 0.78906
# Iter 890, Minibatch Loss= 0.143739, Training Accuracy= 0.79688
# Iter 900, Minibatch Loss= 0.158181, Training Accuracy= 0.77344
# Iter 910, Minibatch Loss= 0.161632, Training Accuracy= 0.73438
# Iter 920, Minibatch Loss= 0.130738, Training Accuracy= 0.82031
# Iter 930, Minibatch Loss= 0.175365, Training Accuracy= 0.75000
# Iter 940, Minibatch Loss= 0.166406, Training Accuracy= 0.77344
# Iter 950, Minibatch Loss= 0.169498, Training Accuracy= 0.75000
# Iter 960, Minibatch Loss= 0.184361, Training Accuracy= 0.69531
# Iter 970, Minibatch Loss= 0.132186, Training Accuracy= 0.85156
# Iter 980, Minibatch Loss= 0.158008, Training Accuracy= 0.75781
# Iter 990, Minibatch Loss= 0.142112, Training Accuracy= 0.78906
# Iter 1000, Minibatch Loss= 0.153315, Training Accuracy= 0.79688
# Iter 1010, Minibatch Loss= 0.144067, Training Accuracy= 0.82031
# Iter 1020, Minibatch Loss= 0.149989, Training Accuracy= 0.77344
# Iter 1030, Minibatch Loss= 0.150322, Training Accuracy= 0.78125
# Iter 1040, Minibatch Loss= 0.160652, Training Accuracy= 0.78125
# Iter 1050, Minibatch Loss= 0.146391, Training Accuracy= 0.77344
# Iter 1060, Minibatch Loss= 0.153170, Training Accuracy= 0.73438
# Iter 1070, Minibatch Loss= 0.144906, Training Accuracy= 0.80469
# Iter 1080, Minibatch Loss= 0.142183, Training Accuracy= 0.79688
# Iter 1090, Minibatch Loss= 0.155993, Training Accuracy= 0.78125
# Iter 1100, Minibatch Loss= 0.155619, Training Accuracy= 0.81250
# Iter 1110, Minibatch Loss= 0.147920, Training Accuracy= 0.79688
# Iter 1120, Minibatch Loss= 0.149989, Training Accuracy= 0.82031
# Iter 1130, Minibatch Loss= 0.165291, Training Accuracy= 0.80469
# Iter 1140, Minibatch Loss= 0.157951, Training Accuracy= 0.72656
# Iter 1150, Minibatch Loss= 0.144838, Training Accuracy= 0.79688
# Iter 1160, Minibatch Loss= 0.143413, Training Accuracy= 0.80469
# Iter 1170, Minibatch Loss= 0.158696, Training Accuracy= 0.82031
# Iter 1180, Minibatch Loss= 0.141250, Training Accuracy= 0.78906
# Iter 1190, Minibatch Loss= 0.146642, Training Accuracy= 0.76562
# Iter 1200, Minibatch Loss= 0.154979, Training Accuracy= 0.76562
# Iter 1210, Minibatch Loss= 0.146463, Training Accuracy= 0.82031
# Iter 1220, Minibatch Loss= 0.127431, Training Accuracy= 0.83594
# Iter 1230, Minibatch Loss= 0.165683, Training Accuracy= 0.76562
# Iter 1240, Minibatch Loss= 0.157214, Training Accuracy= 0.75781
# Iter 1250, Minibatch Loss= 0.161644, Training Accuracy= 0.78125
# Iter 1260, Minibatch Loss= 0.165287, Training Accuracy= 0.76562
# Iter 1270, Minibatch Loss= 0.185155, Training Accuracy= 0.72656
# Iter 1280, Minibatch Loss= 0.138128, Training Accuracy= 0.82031
# Iter 1290, Minibatch Loss= 0.155651, Training Accuracy= 0.78906
# Iter 1300, Minibatch Loss= 0.191146, Training Accuracy= 0.71094
# Iter 1310, Minibatch Loss= 0.178187, Training Accuracy= 0.76562
# Iter 1320, Minibatch Loss= 0.171235, Training Accuracy= 0.76562
# Iter 1330, Minibatch Loss= 0.138635, Training Accuracy= 0.76562
# Iter 1340, Minibatch Loss= 0.144197, Training Accuracy= 0.75000
# Iter 1350, Minibatch Loss= 0.164309, Training Accuracy= 0.78125
# Iter 1360, Minibatch Loss= 0.179885, Training Accuracy= 0.75781
# Iter 1370, Minibatch Loss= 0.149210, Training Accuracy= 0.83594
# Iter 1380, Minibatch Loss= 0.153833, Training Accuracy= 0.82812
# Iter 1390, Minibatch Loss= 0.132695, Training Accuracy= 0.82031
# Iter 1400, Minibatch Loss= 0.138905, Training Accuracy= 0.82812
# Iter 1410, Minibatch Loss= 0.153752, Training Accuracy= 0.78906
# Iter 1420, Minibatch Loss= 0.148195, Training Accuracy= 0.78125
# Iter 1430, Minibatch Loss= 0.184268, Training Accuracy= 0.74219
# Iter 1440, Minibatch Loss= 0.165634, Training Accuracy= 0.72656
# Iter 1450, Minibatch Loss= 0.153687, Training Accuracy= 0.79688
# Iter 1460, Minibatch Loss= 0.156243, Training Accuracy= 0.78125
# Iter 1470, Minibatch Loss= 0.170770, Training Accuracy= 0.71875
# Iter 1480, Minibatch Loss= 0.138486, Training Accuracy= 0.81250
# Iter 1490, Minibatch Loss= 0.136867, Training Accuracy= 0.83594
# Iter 1500, Minibatch Loss= 0.185237, Training Accuracy= 0.68750
# Iter 1510, Minibatch Loss= 0.161397, Training Accuracy= 0.82031
# Iter 1520, Minibatch Loss= 0.146180, Training Accuracy= 0.80469
# Iter 1530, Minibatch Loss= 0.169845, Training Accuracy= 0.73438
# Iter 1540, Minibatch Loss= 0.164673, Training Accuracy= 0.75781
# Iter 1550, Minibatch Loss= 0.138365, Training Accuracy= 0.81250
# Iter 1560, Minibatch Loss= 0.189324, Training Accuracy= 0.71094
# Iter 1570, Minibatch Loss= 0.152391, Training Accuracy= 0.78125
# Iter 1580, Minibatch Loss= 0.180717, Training Accuracy= 0.71875
# Iter 1590, Minibatch Loss= 0.147080, Training Accuracy= 0.77344
# Iter 1600, Minibatch Loss= 0.173118, Training Accuracy= 0.76562
# Iter 1610, Minibatch Loss= 0.130698, Training Accuracy= 0.78906
# Iter 1620, Minibatch Loss= 0.146499, Training Accuracy= 0.83594
# Iter 1630, Minibatch Loss= 0.163178, Training Accuracy= 0.72656
# Iter 1640, Minibatch Loss= 0.134416, Training Accuracy= 0.83594
# Iter 1650, Minibatch Loss= 0.152919, Training Accuracy= 0.76562
# Iter 1660, Minibatch Loss= 0.196494, Training Accuracy= 0.70312
# Iter 1670, Minibatch Loss= 0.157067, Training Accuracy= 0.75781
# Iter 1680, Minibatch Loss= 0.138326, Training Accuracy= 0.82812
# Iter 1690, Minibatch Loss= 0.172236, Training Accuracy= 0.75781
# Iter 1700, Minibatch Loss= 0.179260, Training Accuracy= 0.69531
# Iter 1710, Minibatch Loss= 0.144937, Training Accuracy= 0.81250
# Iter 1720, Minibatch Loss= 0.136282, Training Accuracy= 0.78906
# Iter 1730, Minibatch Loss= 0.157838, Training Accuracy= 0.79688
# Iter 1740, Minibatch Loss= 0.171709, Training Accuracy= 0.72656
# Iter 1750, Minibatch Loss= 0.131451, Training Accuracy= 0.81250
# Iter 1760, Minibatch Loss= 0.155022, Training Accuracy= 0.77344
# Iter 1770, Minibatch Loss= 0.148789, Training Accuracy= 0.76562
# Iter 1780, Minibatch Loss= 0.164773, Training Accuracy= 0.78906
# Iter 1790, Minibatch Loss= 0.166180, Training Accuracy= 0.78125
# Iter 1800, Minibatch Loss= 0.133238, Training Accuracy= 0.83594
# Iter 1810, Minibatch Loss= 0.183518, Training Accuracy= 0.73438
# Iter 1820, Minibatch Loss= 0.174485, Training Accuracy= 0.75000
# ...
# Iter 350, Minibatch Loss= 0.135626, Training Accuracy= 0.79688
# Iter 360, Minibatch Loss= 0.112738, Training Accuracy= 0.82031
# Iter 370, Minibatch Loss= 0.139185, Training Accuracy= 0.78906
# Iter 380, Minibatch Loss= 0.145091, Training Accuracy= 0.80469
# Iter 390, Minibatch Loss= 0.106156, Training Accuracy= 0.88281
# Iter 400, Minibatch Loss= 0.123513, Training Accuracy= 0.84375
# Iter 410, Minibatch Loss= 0.119893, Training Accuracy= 0.85156
# Iter 420, Minibatch Loss= 0.137611, Training Accuracy= 0.82031
# Iter 430, Minibatch Loss= 0.113148, Training Accuracy= 0.85938
# Iter 440, Minibatch Loss= 0.125667, Training Accuracy= 0.84375
# Iter 450, Minibatch Loss= 0.119450, Training Accuracy= 0.82031
# Iter 460, Minibatch Loss= 0.131372, Training Accuracy= 0.84375
# Iter 470, Minibatch Loss= 0.117382, Training Accuracy= 0.82031
# Iter 480, Minibatch Loss= 0.163665, Training Accuracy= 0.75781
# Iter 490, Minibatch Loss= 0.118223, Training Accuracy= 0.84375
# Iter 500, Minibatch Loss= 0.150807, Training Accuracy= 0.81250
# Iter 510, Minibatch Loss= 0.147267, Training Accuracy= 0.80469
# Iter 520, Minibatch Loss= 0.117680, Training Accuracy= 0.81250
# Iter 530, Minibatch Loss= 0.140685, Training Accuracy= 0.82031
# Iter 540, Minibatch Loss= 0.153157, Training Accuracy= 0.78125
# Iter 550, Minibatch Loss= 0.124449, Training Accuracy= 0.85156
# Iter 560, Minibatch Loss= 0.151250, Training Accuracy= 0.77344
# Iter 570, Minibatch Loss= 0.107496, Training Accuracy= 0.86719
# Iter 580, Minibatch Loss= 0.135871, Training Accuracy= 0.82031
# Iter 590, Minibatch Loss= 0.137826, Training Accuracy= 0.82031
# Iter 600, Minibatch Loss= 0.127129, Training Accuracy= 0.83594
# Iter 610, Minibatch Loss= 0.134492, Training Accuracy= 0.76562
# Iter 620, Minibatch Loss= 0.144207, Training Accuracy= 0.77344
# Iter 630, Minibatch Loss= 0.123740, Training Accuracy= 0.84375
# Iter 640, Minibatch Loss= 0.125503, Training Accuracy= 0.81250
# Iter 650, Minibatch Loss= 0.112057, Training Accuracy= 0.82812
# Iter 660, Minibatch Loss= 0.128726, Training Accuracy= 0.82031
# Iter 670, Minibatch Loss= 0.108862, Training Accuracy= 0.83594
# Iter 680, Minibatch Loss= 0.136516, Training Accuracy= 0.82812
# Iter 690, Minibatch Loss= 0.142146, Training Accuracy= 0.80469
# Iter 700, Minibatch Loss= 0.125211, Training Accuracy= 0.82031
# Iter 710, Minibatch Loss= 0.146987, Training Accuracy= 0.82031
# Iter 720, Minibatch Loss= 0.110335, Training Accuracy= 0.85938
# Iter 730, Minibatch Loss= 0.111766, Training Accuracy= 0.85938
# Iter 740, Minibatch Loss= 0.120166, Training Accuracy= 0.85156
# Iter 750, Minibatch Loss= 0.137763, Training Accuracy= 0.82812
# Iter 760, Minibatch Loss= 0.111330, Training Accuracy= 0.86719
# Iter 770, Minibatch Loss= 0.123546, Training Accuracy= 0.85156
# Iter 780, Minibatch Loss= 0.110762, Training Accuracy= 0.84375
# Iter 790, Minibatch Loss= 0.134894, Training Accuracy= 0.82812
# Iter 800, Minibatch Loss= 0.120993, Training Accuracy= 0.84375
# Iter 810, Minibatch Loss= 0.142870, Training Accuracy= 0.79688
# Iter 820, Minibatch Loss= 0.133022, Training Accuracy= 0.78906
# Iter 830, Minibatch Loss= 0.144544, Training Accuracy= 0.79688
# Iter 840, Minibatch Loss= 0.114563, Training Accuracy= 0.87500
# Iter 850, Minibatch Loss= 0.099296, Training Accuracy= 0.87500
# Iter 860, Minibatch Loss= 0.134247, Training Accuracy= 0.78906
# Iter 870, Minibatch Loss= 0.137852, Training Accuracy= 0.82812
# Iter 880, Minibatch Loss= 0.120882, Training Accuracy= 0.84375
# Iter 890, Minibatch Loss= 0.146281, Training Accuracy= 0.76562
# Iter 900, Minibatch Loss= 0.130350, Training Accuracy= 0.84375
# Iter 910, Minibatch Loss= 0.150621, Training Accuracy= 0.78125
# Iter 920, Minibatch Loss= 0.168741, Training Accuracy= 0.71094
# Iter 930, Minibatch Loss= 0.115326, Training Accuracy= 0.85938
# Iter 940, Minibatch Loss= 0.117076, Training Accuracy= 0.81250
# Iter 950, Minibatch Loss= 0.138381, Training Accuracy= 0.77344
# Iter 960, Minibatch Loss= 0.166045, Training Accuracy= 0.75000
# Iter 970, Minibatch Loss= 0.107818, Training Accuracy= 0.85156
# Iter 980, Minibatch Loss= 0.132548, Training Accuracy= 0.82031
# Iter 990, Minibatch Loss= 0.125076, Training Accuracy= 0.84375
# Iter 1000, Minibatch Loss= 0.128331, Training Accuracy= 0.82812
# Iter 1010, Minibatch Loss= 0.131302, Training Accuracy= 0.82031
# Iter 1020, Minibatch Loss= 0.120275, Training Accuracy= 0.83594
# Iter 1030, Minibatch Loss= 0.159727, Training Accuracy= 0.76562
# Iter 1040, Minibatch Loss= 0.123399, Training Accuracy= 0.84375
# Iter 1050, Minibatch Loss= 0.155683, Training Accuracy= 0.74219
# Iter 1060, Minibatch Loss= 0.135638, Training Accuracy= 0.78906
# Iter 1070, Minibatch Loss= 0.119676, Training Accuracy= 0.84375
# Iter 1080, Minibatch Loss= 0.127786, Training Accuracy= 0.83594
# Iter 1090, Minibatch Loss= 0.166412, Training Accuracy= 0.74219
# Iter 1100, Minibatch Loss= 0.119001, Training Accuracy= 0.82031
# Iter 1110, Minibatch Loss= 0.107715, Training Accuracy= 0.85938
# Iter 1120, Minibatch Loss= 0.129782, Training Accuracy= 0.82812
# Iter 1130, Minibatch Loss= 0.151514, Training Accuracy= 0.80469
# Iter 1140, Minibatch Loss= 0.114366, Training Accuracy= 0.82812
# Iter 1150, Minibatch Loss= 0.115005, Training Accuracy= 0.88281
# Iter 1160, Minibatch Loss= 0.161734, Training Accuracy= 0.76562
# Iter 1170, Minibatch Loss= 0.132381, Training Accuracy= 0.84375
# Iter 1180, Minibatch Loss= 0.121517, Training Accuracy= 0.84375
# Iter 1190, Minibatch Loss= 0.115657, Training Accuracy= 0.84375
# Iter 1200, Minibatch Loss= 0.116698, Training Accuracy= 0.83594
# Iter 1210, Minibatch Loss= 0.155790, Training Accuracy= 0.79688
# Iter 1220, Minibatch Loss= 0.102775, Training Accuracy= 0.85156
# Iter 1230, Minibatch Loss= 0.142992, Training Accuracy= 0.81250
# Iter 1240, Minibatch Loss= 0.128678, Training Accuracy= 0.83594
# Iter 1250, Minibatch Loss= 0.132383, Training Accuracy= 0.79688
# Iter 1260, Minibatch Loss= 0.113049, Training Accuracy= 0.87500
# Iter 1270, Minibatch Loss= 0.123711, Training Accuracy= 0.82812
# Iter 1280, Minibatch Loss= 0.121242, Training Accuracy= 0.81250
# Iter 1290, Minibatch Loss= 0.131435, Training Accuracy= 0.83594
# Iter 1300, Minibatch Loss= 0.151540, Training Accuracy= 0.76562
# Iter 1310, Minibatch Loss= 0.116649, Training Accuracy= 0.85156
# Iter 1320, Minibatch Loss= 0.126364, Training Accuracy= 0.80469
# Iter 1330, Minibatch Loss= 0.164104, Training Accuracy= 0.77344
# Iter 1340, Minibatch Loss= 0.112287, Training Accuracy= 0.82031
# Iter 1350, Minibatch Loss= 0.135740, Training Accuracy= 0.80469
# Iter 1360, Minibatch Loss= 0.149149, Training Accuracy= 0.78125
# Iter 1370, Minibatch Loss= 0.125499, Training Accuracy= 0.84375
# Iter 1380, Minibatch Loss= 0.150853, Training Accuracy= 0.79688
# Iter 1390, Minibatch Loss= 0.114680, Training Accuracy= 0.83594
# Iter 1400, Minibatch Loss= 0.135404, Training Accuracy= 0.82812
# Iter 1410, Minibatch Loss= 0.117744, Training Accuracy= 0.87500
# Iter 1420, Minibatch Loss= 0.119588, Training Accuracy= 0.87500
# Iter 1430, Minibatch Loss= 0.134464, Training Accuracy= 0.78906
# Iter 1440, Minibatch Loss= 0.119111, Training Accuracy= 0.86719
# Iter 1450, Minibatch Loss= 0.125031, Training Accuracy= 0.85156
# Iter 1460, Minibatch Loss= 0.102845, Training Accuracy= 0.87500
# Iter 1470, Minibatch Loss= 0.149239, Training Accuracy= 0.78125
# Iter 1480, Minibatch Loss= 0.125011, Training Accuracy= 0.84375
# Iter 1490, Minibatch Loss= 0.120043, Training Accuracy= 0.82031
# Iter 1500, Minibatch Loss= 0.139108, Training Accuracy= 0.80469
# Iter 1510, Minibatch Loss= 0.141371, Training Accuracy= 0.81250
# Iter 1520, Minibatch Loss= 0.124299, Training Accuracy= 0.85156
# Iter 1530, Minibatch Loss= 0.145864, Training Accuracy= 0.80469
# Iter 1540, Minibatch Loss= 0.134955, Training Accuracy= 0.82031
# Iter 1550, Minibatch Loss= 0.150856, Training Accuracy= 0.79688
# Iter 1560, Minibatch Loss= 0.133799, Training Accuracy= 0.81250
# Iter 1570, Minibatch Loss= 0.150510, Training Accuracy= 0.79688
# Iter 1580, Minibatch Loss= 0.114035, Training Accuracy= 0.85938
# Iter 1590, Minibatch Loss= 0.145859, Training Accuracy= 0.78125
# Iter 1600, Minibatch Loss= 0.140201, Training Accuracy= 0.79688
# Iter 1610, Minibatch Loss= 0.149342, Training Accuracy= 0.76562
# Iter 1620, Minibatch Loss= 0.161230, Training Accuracy= 0.79688
# Iter 1630, Minibatch Loss= 0.111590, Training Accuracy= 0.85938
# Iter 1640, Minibatch Loss= 0.130039, Training Accuracy= 0.82031
# Iter 1650, Minibatch Loss= 0.107058, Training Accuracy= 0.83594
# Iter 1660, Minibatch Loss= 0.133080, Training Accuracy= 0.81250
# Iter 1670, Minibatch Loss= 0.120315, Training Accuracy= 0.85938
# Iter 1680, Minibatch Loss= 0.127939, Training Accuracy= 0.80469
# Iter 1690, Minibatch Loss= 0.141075, Training Accuracy= 0.76562
# Iter 1700, Minibatch Loss= 0.132575, Training Accuracy= 0.80469
# Iter 1710, Minibatch Loss= 0.142417, Training Accuracy= 0.82812
# Iter 1720, Minibatch Loss= 0.142517, Training Accuracy= 0.81250
# Iter 1730, Minibatch Loss= 0.100629, Training Accuracy= 0.86719
# Iter 1740, Minibatch Loss= 0.125371, Training Accuracy= 0.83594
# Iter 1750, Minibatch Loss= 0.135795, Training Accuracy= 0.82812
# Iter 1760, Minibatch Loss= 0.150035, Training Accuracy= 0.78125
# Iter 1770, Minibatch Loss= 0.123043, Training Accuracy= 0.82812
# Iter 1780, Minibatch Loss= 0.104576, Training Accuracy= 0.85938
# Iter 1790, Minibatch Loss= 0.124103, Training Accuracy= 0.83594
# Iter 1800, Minibatch Loss= 0.115001, Training Accuracy= 0.82812
# Iter 1810, Minibatch Loss= 0.113235, Training Accuracy= 0.86719
# Iter 1820, Minibatch Loss= 0.133412, Training Accuracy= 0.79688
# Iter 1830, Minibatch Loss= 0.115758, Training Accuracy= 0.83594
# Iter 1840, Minibatch Loss= 0.155074, Training Accuracy= 0.78125
# Iter 1850, Minibatch Loss= 0.105650, Training Accuracy= 0.86719
# Iter 1860, Minibatch Loss= 0.147280, Training Accuracy= 0.78906
# Iter 1870, Minibatch Loss= 0.123584, Training Accuracy= 0.85938
# Iter 1880, Minibatch Loss= 0.119252, Training Accuracy= 0.84375
# Iter 1890, Minibatch Loss= 0.120262, Training Accuracy= 0.85156
# Iter 1900, Minibatch Loss= 0.126643, Training Accuracy= 0.83594
# Iter 1910, Minibatch Loss= 0.153471, Training Accuracy= 0.80469
# Iter 1920, Minibatch Loss= 0.119613, Training Accuracy= 0.86719
# Iter 1930, Minibatch Loss= 0.126764, Training Accuracy= 0.85156
# Iter 1940, Minibatch Loss= 0.135660, Training Accuracy= 0.78125
# Iter 1950, Minibatch Loss= 0.102421, Training Accuracy= 0.85156
# Iter 1960, Minibatch Loss= 0.121548, Training Accuracy= 0.82812
# Iter 1970, Minibatch Loss= 0.136875, Training Accuracy= 0.81250
# Iter 1980, Minibatch Loss= 0.127608, Training Accuracy= 0.86719
# Iter 1990, Minibatch Loss= 0.114146, Training Accuracy= 0.88281
# Iter 2000, Minibatch Loss= 0.142149, Training Accuracy= 0.80469
# Iter 2010, Minibatch Loss= 0.146545, Training Accuracy= 0.78906
# Iter 2020, Minibatch Loss= 0.154828, Training Accuracy= 0.76562
# Iter 2030, Minibatch Loss= 0.114216, Training Accuracy= 0.83594
# Iter 2040, Minibatch Loss= 0.163538, Training Accuracy= 0.75781
# Iter 2050, Minibatch Loss= 0.147960, Training Accuracy= 0.78906
# Iter 2060, Minibatch Loss= 0.108649, Training Accuracy= 0.88281
# Iter 2070, Minibatch Loss= 0.118229, Training Accuracy= 0.87500
# Iter 2080, Minibatch Loss= 0.127180, Training Accuracy= 0.83594
# Iter 2090, Minibatch Loss= 0.123554, Training Accuracy= 0.85156
# Iter 2100, Minibatch Loss= 0.143905, Training Accuracy= 0.78906
# Iter 2110, Minibatch Loss= 0.126331, Training Accuracy= 0.85156
# Iter 2120, Minibatch Loss= 0.128900, Training Accuracy= 0.84375
# Iter 2130, Minibatch Loss= 0.137244, Training Accuracy= 0.82031
# Iter 2140, Minibatch Loss= 0.152346, Training Accuracy= 0.78906
# Iter 2150, Minibatch Loss= 0.125721, Training Accuracy= 0.83594
# Iter 2160, Minibatch Loss= 0.128737, Training Accuracy= 0.81250
# Iter 2170, Minibatch Loss= 0.147923, Training Accuracy= 0.80469
# Iter 2180, Minibatch Loss= 0.117915, Training Accuracy= 0.83594
# Iter 2190, Minibatch Loss= 0.137861, Training Accuracy= 0.79688
# Iter 2200, Minibatch Loss= 0.132596, Training Accuracy= 0.80469
# Iter 2210, Minibatch Loss= 0.123758, Training Accuracy= 0.82812
# Iter 2220, Minibatch Loss= 0.114930, Training Accuracy= 0.84375
# Iter 2230, Minibatch Loss= 0.144602, Training Accuracy= 0.78906
# Iter 2240, Minibatch Loss= 0.137380, Training Accuracy= 0.82812
# Iter 2250, Minibatch Loss= 0.118094, Training Accuracy= 0.82812
# Iter 2260, Minibatch Loss= 0.139868, Training Accuracy= 0.78906
# Iter 2270, Minibatch Loss= 0.118555, Training Accuracy= 0.84375
# Iter 2280, Minibatch Loss= 0.129381, Training Accuracy= 0.80469
# Iter 2290, Minibatch Loss= 0.125375, Training Accuracy= 0.81250
# Iter 2300, Minibatch Loss= 0.115010, Training Accuracy= 0.85938
# Iter 2310, Minibatch Loss= 0.128447, Training Accuracy= 0.79688
# Iter 2320, Minibatch Loss= 0.146087, Training Accuracy= 0.80469
# Iter 2330, Minibatch Loss= 0.117607, Training Accuracy= 0.82031
# Iter 2340, Minibatch Loss= 0.154597, Training Accuracy= 0.79688
# Iter 2350, Minibatch Loss= 0.114818, Training Accuracy= 0.86719
# Iter 2360, Minibatch Loss= 0.136228, Training Accuracy= 0.79688
# Iter 2370, Minibatch Loss= 0.154602, Training Accuracy= 0.78906
# Iter 2380, Minibatch Loss= 0.119355, Training Accuracy= 0.85156
# Iter 2390, Minibatch Loss= 0.114924, Training Accuracy= 0.85938
# Iter 2400, Minibatch Loss= 0.148724, Training Accuracy= 0.78125
# Iter 2410, Minibatch Loss= 0.136319, Training Accuracy= 0.78906
# Iter 2420, Minibatch Loss= 0.117184, Training Accuracy= 0.85938
# Iter 2430, Minibatch Loss= 0.122939, Training Accuracy= 0.81250
# Iter 2440, Minibatch Loss= 0.123001, Training Accuracy= 0.82031
# Iter 2450, Minibatch Loss= 0.122256, Training Accuracy= 0.85156
# Iter 2460, Minibatch Loss= 0.109341, Training Accuracy= 0.85156
# Iter 2470, Minibatch Loss= 0.121488, Training Accuracy= 0.83594
# Iter 2480, Minibatch Loss= 0.145249, Training Accuracy= 0.77344
# Iter 2490, Minibatch Loss= 0.118968, Training Accuracy= 0.85938
# Iter 2500, Minibatch Loss= 0.134817, Training Accuracy= 0.78906
# Iter 2510, Minibatch Loss= 0.145259, Training Accuracy= 0.82031
# Iter 2520, Minibatch Loss= 0.140738, Training Accuracy= 0.80469
# Iter 2530, Minibatch Loss= 0.152743, Training Accuracy= 0.76562
# Iter 2540, Minibatch Loss= 0.142537, Training Accuracy= 0.77344
# Iter 2550, Minibatch Loss= 0.139916, Training Accuracy= 0.80469
# Iter 2560, Minibatch Loss= 0.151582, Training Accuracy= 0.77344
# Iter 2570, Minibatch Loss= 0.162719, Training Accuracy= 0.72656
# Iter 2580, Minibatch Loss= 0.115405, Training Accuracy= 0.84375
# Iter 2590, Minibatch Loss= 0.129280, Training Accuracy= 0.84375
# Iter 2600, Minibatch Loss= 0.140513, Training Accuracy= 0.82812
# Iter 2610, Minibatch Loss= 0.148257, Training Accuracy= 0.75000
# Iter 2620, Minibatch Loss= 0.122412, Training Accuracy= 0.84375
# Iter 2630, Minibatch Loss= 0.130038, Training Accuracy= 0.78125
# Iter 2640, Minibatch Loss= 0.134913, Training Accuracy= 0.82031
# Iter 2650, Minibatch Loss= 0.130306, Training Accuracy= 0.79688
# Iter 2660, Minibatch Loss= 0.130370, Training Accuracy= 0.82812
# Iter 2670, Minibatch Loss= 0.134936, Training Accuracy= 0.82031
# Iter 2680, Minibatch Loss= 0.118322, Training Accuracy= 0.85156
# Iter 2690, Minibatch Loss= 0.136825, Training Accuracy= 0.80469
# Iter 2700, Minibatch Loss= 0.129162, Training Accuracy= 0.84375
# Iter 2710, Minibatch Loss= 0.135696, Training Accuracy= 0.83594
# Iter 2720, Minibatch Loss= 0.132144, Training Accuracy= 0.79688
# Iter 2730, Minibatch Loss= 0.147826, Training Accuracy= 0.77344
# Iter 2740, Minibatch Loss= 0.170103, Training Accuracy= 0.75781
# Iter 2750, Minibatch Loss= 0.121708, Training Accuracy= 0.86719
# Iter 2760, Minibatch Loss= 0.140680, Training Accuracy= 0.80469
# Iter 2770, Minibatch Loss= 0.136359, Training Accuracy= 0.83594
# Iter 2780, Minibatch Loss= 0.114193, Training Accuracy= 0.88281
# Iter 2790, Minibatch Loss= 0.132292, Training Accuracy= 0.80469
# Iter 2800, Minibatch Loss= 0.098257, Training Accuracy= 0.85938
# Iter 2810, Minibatch Loss= 0.114809, Training Accuracy= 0.85156
# Iter 2820, Minibatch Loss= 0.159891, Training Accuracy= 0.78906
# Iter 2830, Minibatch Loss= 0.123315, Training Accuracy= 0.82031
# Iter 2840, Minibatch Loss= 0.120577, Training Accuracy= 0.83594
# Testing accuracy = 0.80583
# training finished.
